# %%
# String Datatype
# Collection of charater is called string data
# Example 'abcd'
# String is immutable -- object --> forcefully --> address change
# String supports indexing and slicing
# String supports mathematically operator +,*,<>,=

# %%
#  string 
a = 'Hello'
print(a)
print(type(a))
# Out:
# Hello
# <class 'str'>

# %%
b = "Hello World"
print(b)
print(type(b))
# Out:
# Hello World
# <class 'str'>

# %%
c = '''Good
Morning
Welcome 
to 
Python
Class '''
print(c)
print(type(c))
# Out:
# Good
# Morning
# Welcome
# to
# Python
# Class
# <class 'str'>

# %%
d = """Good
Evening
Welcome 
to 
Python
Class """
print(d)
print(type(d))
# Out:
# Good
# Evening
# Welcome
# to
# Python
# Class
# <class 'str'>

# %%
#Immutable
a = 'soft'
a[0] = 'z'
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 a = 'soft'
# ----> 2 a[0] = 'z'
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment

# %%
a = 'soft'
print(id(a))
a = a + 'ronix'
print(a)
print(id(a))
# Out:
# 1669274908688
# softronix
# 1669298309296

# %%
# Indexing and slicing
s = 'NANDANVAN'
# Forward indexing
print(s[5])
# Out:
# N

# %%
print(s[6])
# Out:
# V

# %%
print(s[0])
# Out:
# N

# %%
# Backward indexing
print(s[-6])
# Out:
# D

# %%
print(s[-8])
# Out:
# A

# %%
# slicing
print(s[0:3])  # [start:end-1]
# Out:
# NAN

# %%
print(s[0:6])
# Out:
# NANDAN

# %%
print(s[:])
# Out:
# NANDANVAN

# %%
print(s[0:9:2])  #[start:end-1:step]
# Out:
# NNAVN

# %%
print(s[0:7:2])
# Out:
# NNAV

# %%
print(s[0:6:2])
# Out:
# NNA

# %%
s = "Softronix"
# forward direction indexing
print(s[2])
# Out:
# f

# %%
print(s[8])
# Out:
# x

# %%
# backward direction indexing
print(s[-5])
# Out:
# r

# %%
print(s[-7])
# Out:
# f

# %%
# slicing
#[start:end-1]
print(s[0:4])
# Out:
# Soft

# %%
print(s[:])
# Out:
# Softronix

# %%
s = "Softronix"
print(s[0:9:2]) #[start:end-1:step]
# Out:
# Sfrnx

# %%
print(s[0:4:2])
# Out:
# Sf

# %%
# mathematically
a = "soft"
b = "tronix"
print(a+b)
# Out:
# softtronix

# %%
print('IT '*10)
# Out:
# IT IT IT IT IT IT IT IT IT IT

# %%
print('-'*20)
# Out:
# --------------------

# %%
print('A'=='B')  # Asci code
# Out:
# False

# %%
print('10' == '20')
# Out:
# False

# %%
print('10'<'20')
# Out:
# True

# %%
print('10'>'20')
# Out:
# False

# %%
# string function
# len()
a = "soft"
print(len(a))
# Out:
# 4

# %%
b = "Good Evening"
print(len(b))
# Out:
# 12

# %%
c = "Softronix_IT Services"
print(len(c))
# Out:
# 21

# %%
#input()  -- > string
a = input("Enter the string1")
b = input("Enter the string2")
print(a)
print(b)
print(a+b)
# Out:
# Enter the string1 hello
# Enter the string2 python
# hello
# python
# hellopython

# %%
a = input("Enter the num1")
b = input("Enter the num2")
print(a)
print(b)
print(a+b)
# Out:
# Enter the num1 10
# Enter the num2 20
# 10
# 20
# 1020

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
# eval  --> convert 
a = eval(input("Enter the string1"))
b = eval(input("Enter the string2"))
print(a)
print(b)
print(a+b)
# Out:
# Enter the string1 10
# Enter the string2 20
# 10
# 20
# 30

# %%
# lower
a = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
print(a.lower())
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
b = "PytHoN"
print(b.lower())
# Out:
# python

# %%
# upper()
c = "abcdefghijklmnopqrstuvwxyz"
print(c.upper())
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
b = "PytHoN"
print(b.upper())
# Out:
# PYTHON

# %%
#title()
d = "softronix it services"
print(d.title())
# Out:
# Softronix It Services

# %%
e = "good morning"
print(e.title())
# Out:
# Good Morning

# %%
# capitalize()
f = "hello good morning everyone"
print(f.capitalize())
# Out:
# Hello good morning everyone

# %%
g = "hello world hello python"
print(g.capitalize())
# Out:
# Hello world hello python

# %%
# swapcase
h = "AbCdEfGhI"
print(h.swapcase())
# Out:
# aBcDeFgHi

# %%
i = "good MORNING"
print(i.swapcase())
# Out:
# GOOD morning

# %%
# lstrip()
a = "          Hello          "
print(len(a))
b = a.lstrip()
print(b)
print(len(b))

c = "                     "
print(len(c))
d = c.lstrip()
print(d)
print(len(d))
# Out:
# 25
# Hello
# 15
# 21
#
# 0

# %%
# rstrip()
a = "         Python        "
print(len(a))
b = a.rstrip()
print(b)
print(len(b))
# Out:
# 23
#          Python
# 15

# %%
# strip()
a = "           Softronix        "
print(len(a))
b = a.strip()
print(b)
print(len(b))
# Out:
# 28
# Softronix
# 9

# %%
# removeprefix
c = "unhappy"
print(c.removeprefix('un'))
# Out:
# happy

# %%
d = "preprocessing"
print(d.removeprefix('pre'))
# Out:
# processing

# %%
# removesuffix
f = "notes.pdf"
print(f.removesuffix('.pdf'))
# Out:
# notes

# %%
g = 'file.txt'
print(g.removesuffix('.txt'))
# Out:
# file

# %%
# find()
a = "Nandanvan"  #--> 0
print(a.find('v'))
# Out:
# 6

# %%
print(a.find('d'))
# Out:
# 3

# %%
print(a.find('z'))
# Out:
# -1

# %%
print(a.find('x'))
# Out:
# -1

# %%
# index()
a = "Nandanvan"
print(a.index('N'))
# Out:
# 0

# %%
print(a.index('n'))
# Out:
# 2

# %%
print(a.index('z'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(a.index('z'))
#
# ValueError: substring not found

# %%
#count
a = "Nandanvan"
print(a.count('n'))
# Out:
# 3

# %%
print(a.count('a'))
# Out:
# 3

# %%
b = "softronix"
print(b.count('o'))
# Out:
# 2

# %%
# startswith()
a = "softronix"
print(a.startswith('ix'))
# Out:
# False

# %%
print(a.startswith('so'))
# Out:
# True

# %%
# endswith
a = "softronix"
print(a.endswith('ix'))
# Out:
# True

# %%
print(a.endswith('so'))
# Out:
# False

# %%
# Replace()
a = "Hello World"
print(a.replace('World','Python'))
# Out:
# Hello Python

# %%
b = "Good Morning"
print(b.replace('Morning','Evening'))
# Out:
# Good Evening

# %%
#split()
a = "apple berry cherry mango kiwi"
print(a.split())
# Out:
# ['apple', 'berry', 'cherry', 'mango', 'kiwi']

# %%
b = "Hello good evening everyone"
print(b.split())
# Out:
# ['Hello', 'good', 'evening', 'everyone']

# %%
# splitlines()  --> \n--> new line
a = "Hello\nWorld\nPython"
print(a.splitlines())
# Out:
# ['Hello', 'World', 'Python']

# %%
v = "Cars\nBikes\nVehicles"
print(v.splitlines())
# Out:
# ['Cars', 'Bikes', 'Vehicles']

# %%
# join()
a = ["Hello","Python"]
print(" ".join(a))
# Out:
# Hello Python

# %%
b = ["Good", "Evening"]
print(" ".join(b))
# Out:
# Good Evening

# %%
#ljust
a = "hi"
print(a.ljust(7,'*'))
# Out:
# hi*****

# %%
#rjust
print(a.rjust(7,'*'))
# Out:
# *****hi

# %%
#center
print(a.center(7,'-'))
# Out:
# ---hi--

# %%
#zfill
num = '4'
print(num.zfill(8))
# Out:
# 00000004

# %%
s = "hi"
print(s.zfill(6))
# Out:
# 0000hi

# %%
# format() --> {} -->placeholder
name = "Tanu"
age = 25
print("My name is {}.I am {} years old".format(name,age))
# Out:
# My name is Tanu.I am 25 years old

# %%
# f-string
name = "Tanu"
age = 25
print(f"My name is {name}.I am {age} years old")
# Out:
# My name is Tanu.I am 25 years old

# %%
# isalpha() -->alphabets
a = "python"
print(a.isalpha())
# Out:
# True

# %%
b = "JAVA"
print(b.isalpha())
# Out:
# True

# %%
c = "Python1234"
print(c.isalpha())
# Out:
# False

# %%
# isdigit()
d = "1234567"
print(d.isdigit())
# Out:
# True

# %%
e = "123456789khcf"
print(e.isdigit())
# Out:
# False

# %%
# isalnum()
f = "hello1234"
print(f.isalnum())
# Out:
# True

# %%
g = "srtyuikjhsvs"
print(g.isalnum())
# Out:
# True

# %%
h = "234567890987654"
print(h.isalnum())
# Out:
# True

# %%
# isspace()
i = " "
print(i.isspace())
# Out:
# True

# %%
j = "  j  "
print(j.isspace())
# Out:
# False

# %%
# istitle()
k = "Hello python"
print(k.istitle())
# Out:
# False

# %%
k = "Hello Python"
print(k.istitle())
# Out:
# True

# %%
# isupper()
l = "rtyuiolkjxcvbnm"
print(l.isupper())
# Out:
# False

# %%
l = "SDFGHPPHGFDSXCVBNM"
print(l.isupper())
# Out:
# True

# %%
# islower
m = "wertyuiopgfdxcvbnm"
print(m.islower())
# Out:
# True

# %%
# Encode --> human to machine
#Decode --> Machine to human
n = "sushani1234@gmail.com"
a = n.encode()
print(a)
# Out:
# b'sushani1234@gmail.com'

# %%
print(a.decode())
# Out:
# sushani1234@gmail.com
