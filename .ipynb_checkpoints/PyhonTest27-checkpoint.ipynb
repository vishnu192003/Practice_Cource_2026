# %%
#1)
parks = ['Zion','Everglades','Yosemite','Grand Canyon','Yellowstone']
longest_park = max(parks, key=len)
print(longest_park)
# Out:
# Grand Canyon

# %%
#2)
x = 0
for i in range(10):
	if i == 3:
		break
	x +=i
else:
	x = -1
print(x)
# Out:
# 3

# %%
#3)
cars = ["porche","BMW","Audi"]
treading=[]
for c in cars:
	if c == "BMW" or "Porsche":
		treading.append(c)
print(treading)
# Out:
# ['porche', 'BMW', 'Audi']

# %%
#4)
num = [1,2,3,4]
num.remove(2)
num.pop(1)
print(num)
# Out:
# [1, 4]

# %%
#5)
if []:
	print('Yes')
else: 
	print('No')
# Out:
# No

# %%
#6)
a = None

if a is None:
    print('a is none')
# Out:
# a is none

# %%
# 7)
cart = ['Laptop','Mouse','Keyboard']
print(' | '.join(cart))
# Out:
# Laptop | Mouse | Keyboard

# %%
# 8)

a = 5
b=10
a,b = b,a
print(a,b)
# Out:
# 10 5

# %%
# 9)
food = 'Pasta'
food.replace('a','e')
print(food)
# Out:
# Pasta

# %%
# 10)
x = [1,2]
x.extend([3,4])
print(sum(x))
# Out:
# 10

# %%
# 11)
a = [1,2,3,4,5]
b = a[:]
b[2] = 9
print(b)
# Out:
# [1, 2, 9, 4, 5]

# %%
# 12)
a = 256
b = 256
c = 257
d = 257

print(a is b, c is d)
# Out:
# True False

# %%
# 13)

print(len('Hello\n'))
# Out:
# 6

# %%
# 14)
x = [1,2,3]
y = x.copy()
y[1] = 99
print(y)
# Out:
# [1, 99, 3]

# %%
# 15)
s = ('banana')
print(len(s))
print(type(s))
# Out:
# 6
# <class 'str'>

# %%
# 16)
a = '10'
b = '2'
print(a>b)
# Out:
# False

# %%
# 17)Which is faster and Consume less memory ? Tuple or List and why ?
# Out:
# 88
# 64

# %%
# 18)
i = ('preprocessing py')
print(i.title())
# Out:
# Preprocessing Py

# %%
# 19)
print('3'+'4'*2)
# Out:
# 344

# %%
# 20)
print('Hello World'[::1][-5:])
# Out:
# World

# %%
#21)
s = 'hello'
t = s 
v= t.upper()
print(v)
# Out:
# HELLO

# %%
# 22)
nums = [10,20,30,40,60]
nums.remove(20)
nums.pop(1)
print(nums)
# Out:
# [10, 40, 60]

# %%
# 23)
text ='Banana'
b=text.upper()
v=b.replace('A', 'M')
print(v)
# Out:
# BMNMNM

# %%
#24)
x = (1,2,[3,4])
x[2].append(5)
print(x)
# Out:
# (1, 2, [3, 4, 5])

# %%
# 25)
cities = ['Delhi','Mumbai','Chennai']
print(min(cities))
# Out:
# Chennai

# %%
# 26)
a = 5
b = 10
print(a + b *2)
# Out:
# 25

# %%
# 27)
a = '5'
b = 3
print(a*b)
# Out:
# 555

# %%
# 28)
arr = [1,2,3]
x = arr
x.append(4)
print(x)
# Out:
# [1, 2, 3, 4]

# %%
# 29)
word = 'python'
print(word.upper()[0])
# Out:
# P

# %%
# 30)Which of the following gives an error?
# 1)int(‘9.5’)
# 2)bool(0b1001)
# 3)float(‘9.4’)
# 4)All of the above

##ANSWER: 4)All of the above

# 31) Difference between List and Tuple

##ANSWER:
## list: mutable,[],hetrogeneous
## tuple: immutable,(),hetrogeneous
