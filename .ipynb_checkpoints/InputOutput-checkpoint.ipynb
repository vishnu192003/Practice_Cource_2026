# %% [markdown]
# ## input And Output

# %%
## write a program to read 2 numbers from the keyboard and print sum


a=int(input('enter num1'))
b=int(input('enter num2'))
print(a+b)
# Out:
# enter num1 10
# enter num2 20
# 30

# %%
a=(input('enter num1'))
b=(input('enter num2'))
i=int(a)
j=int(b)
print(i+j)
# Out:
# enter num1 40
# enter num2 50
# 90

# %%
print("The Sum: ",int(input("Enter Num1"))+int(input("Enter Num2")))
# Out:
# Enter Num1 10
# Enter Num2 20
# The Sum:  30

# %% [markdown]
# # write a program to read employee data from
# ## the keyboard and print that data
# ## emp_id  , emp name , emp add , emp salary, emp married or unmarried
#
# a=int(input('Enter EMP ID:'))
# b=input('Enter EMP Name:')
# c=input('Enter EMP ADD:')
# d=float(input('Enter EMP Salary:'))
# e=bool(input('Enter EMP  Married/Unmarried:'))
# print('------------------------------------')
# print("Emp ID: ", a ,"Emp Name: ", b,"Emp ADD: ", c,"Emp SAL: ", d,"Emp M_STATUS: ", e)

# %% [markdown]
# ## how to read multiple values from the keyboard in  a single line

# %%
print("EMPLOYEE_DATA:", int(input("Enter EMP_ID: ")), input("Enter EMP_NAME: "), input("Enter EMP_ADD: "), float(input("Enter EMP_SAL: ")))
# Out:
# Enter EMP_ID:  987
# Enter EMP_NAME:  vishnu
# Enter EMP_ADD:  ngp
# Enter EMP_SAL:  87410.00
# EMPLOYEE_DATA: 987 vishnu ngp 87410.0 --------------

# %%
EMP_ID, Emp_Name, EMP_Salary = input("Enter three values: ").split()

print("EMP_ID:",EMP_ID)
print("Emp_Name:",Emp_Name)
print("EMP_Salary:",EMP_Salary)
# Out:
# Enter three values:  41 v 65410.11
# EMP_ID: 41
# Emp_Name v
# EMP_Salary 65410.11

# %%
age, name, salary = input().split()

age = int(age)
name= str(name)
salary = float(salary)

print("-"*30)
print(age)
print(name)
print(salary)
# Out:
#  23 vishnu 87410.00
# ------------------------------
# 23
# vishnu
# 87410.0
