# %% [markdown]
# ## input output

# %%
## how to read multiple values from the keyboard in  a single line

# %%
print("EMPLOYEE_DATA:", int(input("Enter EMP_ID: ")), input("Enter EMP_NAME: "), input("Enter EMP_ADD: "), float(input("Enter EMP_SAL: ")))
# Out:
# Enter EMP_ID:  1478963
# Enter EMP_NAME:  vishnu
# Enter EMP_ADD:  kabir nagar
# Enter EMP_SAL:  87410.00
# EMPLOYEE_DATA: 1478963 vishnu kabir nagar 87410.0

# %%
## how to read multiple values from the keyboard in  a single line

a,b = (int(x) for x in input ("enter num").split())
print("the sum : ", a+b)
# Out:
# enter num 10 20
# the sum :  30

# %%
a,b,c = (int(x) for x in input ("enter num").split())
print("the sum : ", a+b+c)
# Out:
# enter num 10 20 30
# the sum :  60
