# %%
## byte datatype --------> video audio 
## byte datatype represent a group of byte number just like an array
## (0,256)
## immutable

# %%
l= [10,20,30,40]
b= bytes(l)
print(type(b))
print(b)
# Out:
# <class 'bytes'>
# b'\n\x14\x1e('

# %%
l= [10,20,30,40,255]
b= bytes(l)
print(type(b))
print(b)
# Out:
# <class 'bytes'>
# b'\n\x14\x1e(\xff'

# %%
l= [10,20,30,40,259]
b= bytes(l)
print(type(b))
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 l= [10,20,30,40,259]
# ----> 2 b= bytes(l)
#       3 print(type(b))
#       4 print(b)
#
# ValueError: bytes must be in range(0, 256)

# %%
## (0,256) -----> immutable

g=b[3] = 40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 ## (0,256) -----> immutable
#       2
# ----> 3 g=b[3] = 40
#
# TypeError: 'bytes' object does not support item assignment
