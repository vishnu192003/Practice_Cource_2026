# %% [markdown]
# ## complex datatypes

# %%
d= 64/84j
print(d)
print(d.real)
print(d.imag)
# Out:
# -0.7619047619047619j
# 0.0
# -0.7619047619047619

# %%
print(type(d))
# Out:
# <class 'complex'>

# %% [markdown]
# ## OPERATIONS

# %%
h= 3+2j
i= 4+9j
k= h+i
print(k)
print(type(k))
# Out:
# (7+11j)
# <class 'complex'>

# %% [markdown]
# ## BOOLEAN

# %%
a= True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
b= True+False
print(b)
# Out:
# 1

# %%
c= True+True
print(c)
# Out:
# 2

# %%
d= False+False
print(d)
# Out:
# 0

# %%
e= True+True
print(e)
# Out:
# 2

# %%
f= True*True
print(f)
# Out:
# 1

# %%
f= True*False
print(f)
# Out:
# 0

# %%
##string

# %%
s= 'asdfghjk'
s[2] = e
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 s= 'asdfghjk'
# ----> 2 s[2] = e
#       3 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
v= 'asdfg'+"sdfgh"
print(v)
# Out:
# asdfgsdfgh

# %%
n= ''' vishnu 
njdfhoi
jkfh g
nlelt'''
print(n)
# Out:
#  vishnu
# njdfhoi
# jkfh g
# nlelt

# %%
p= """ 
welcome
to
softronix
"""
print(p)
# Out:
#
# welcome
# to
# softronix

# %% [markdown]
# ## indexing

# %%
#forward direction indexing...

# %%
a="antuciast 4 devops"
print(a)
print(a[0:9])
print(a[9:19])
print(a[::])
print(a[::3])
# Out:
# antuciast 4 devops
# antuciast
#  4 devops
# antuciast 4 devops
# aua do

# %%
#backward direction indexing...

# %%
App = input("Enter your Favourite App")
if App == "Amazon":  
  	print("50% Off")
elif App == "Flipkart":    
	print("80% Off")
elif App == "Meesho":   
 	print("60% Off")
elif App == "Nyka":   
 	print("Buy 1 get 1 Free")
else:   
 	print("Not recommended brand entered")
# Out:
# Enter your Favourite App Nyka
# Buy 1 get 1 Free

# %%
for i in range(10): 
	if i==7: 
		print("processing is enough..plz break") 
		break 
	print(i)
print("outside of loop")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# processing is enough..plz break
# outside of loop

# %%
v= 'vishnu '* 10
print(v)
print ()
d= 'asdfghjklqwertyuio'
e= ' '
f= "sdfghjkliuytrersfc"
print(d+e+f)

g= d+f
print(g)
print(len(g))
print(d<f)
print(f<d)
# Out:
# vishnu vishnu vishnu vishnu vishnu vishnu vishnu vishnu vishnu vishnu
#
# asdfghjklqwertyuio sdfghjkliuytrersfc
# asdfghjklqwertyuiosdfghjkliuytrersfc
# 36
# True
# False

# %%
a=input('whats your name')
v=input('whats your fav fruits')
print(type(a))
# Out:
# whats your name xcvbnm,
# whats your fav fruits cvbnm'
# <class 'str'>

# %%
x= 'qertyuiolkjhgfdsvbnzxcvbnm'
y= 'QWERTYUIOPASDFGHJKL'

print(y.lower())
print(x.upper())
# Out:
# qwertyuiopasdfghjkl
# QERTYUIOLKJHGFDSVBNZXCVBNM

# %%
spam = 40
eggs = 2
print(spam + eggs + spam)
# Out:
# 82
