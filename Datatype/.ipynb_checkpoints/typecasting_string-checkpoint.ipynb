# %%
print("int datatype intopo str datatype: ", str(102))
# Out:
# int datatype intopo str datatype:  102

# %%
print("int datatype intopo str datatype: ", str(20))
# Out:
# int datatype intopo str datatype:  20

# %%
## COMPLEX TO STR()

# %%
print("COMPLEX datatype intopo str datatype: ", str('20+2j'))
# Out:
# COMPLEX datatype intopo str datatype:  20+2j

# %%
# Float to Str()

# %%
print("Float datatype intopo str datatype: ", str('True'))
# Out:
# Float datatype intopo str datatype:  True

# %%
print("Float datatype intopo str datatype: ", str('False'))
# Out:
# Float datatype intopo str datatype:  False

# %% [markdown]
# ## BOOl ()

# %%
## bool ()
## we can use this function to convert other type of values to bool type.

# %%
## int to bool()

print("int datatype into bool datatype: ", bool(1))
# Out:
# int datatype intopo bool datatype:  True

# %%
print("int datatype into bool datatype: ", bool(0))
# Out:
# int datatype intopo bool datatype:  False

# %%
print("int datatype into bool datatype: ", bool(000))
# Out:
# int datatype intopo bool datatype:  False

# %%
## float to bool ()

# %%
print("float datatype into bool datatype: ", bool(20.10))
# Out:
# float datatype into bool datatype:  True

# %%
print("float datatype into bool datatype: ", bool(20.2665410))
# Out:
# float datatype into bool datatype:  True

# %%
print("float datatype into bool datatype: ", bool(00.0))
# Out:
# float datatype into bool datatype:  False

# %%
# complex to bool

# %%
# string to bool ()

# %%
print("string datatype into bool datatype: ", bool('v'))
# Out:
# string datatype into bool datatype:  True

# %%
print("string datatype into bool datatype: ", bool('10'))
# Out:
# string datatype into bool datatype:  True

# %%
print("string datatype into bool datatype: ", bool('7419562'))
# Out:
# string datatype into bool datatype:  True

# %%
print("string datatype into bool datatype: ", bool('0'))
# Out:
# string datatype into bool datatype:  True

# %%
## string to complex

# %%
print("string datatype into complex datatype: ", complex('4'+ '1'))
# Out:
# string datatype into complex datatype:  (41+0j)

# %%
print("string datatype into complex datatype: ", complex('04'+ '1'))
# Out:
# string datatype into complex datatype:  (41+0j)

# %%
# float to complex

# %%
print("float datatype into complex datatype: ", complex(True))
# Out:
# float datatype into complex datatype:  (1+0j)

# %%
print("float datatype into complex datatype: ", complex(False))
# Out:
# float datatype into complex datatype:  0j
