# %%
#list ordered
o= [1,2,3,4,5,6,7,8,9]
print(o)



print("MUTABLE")
v= [751649,884,6,654546,546,]
print(v)
print(type(v))
print(id(v))

print(v.append(60))
print(v)
print(type(v))
print(id(v))

print(v[3])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# MUTABLE
# [751649, 884, 6, 654546, 546]
# <class 'list'>
# 2428104891072
# None
# [751649, 884, 6, 654546, 546, 60]
# <class 'list'>
# 2428104891072
# 654546

# %%
s= [10,20,30,40]

f= s.append(60)
print(s)
# Out:
# None

# %% [markdown]
# ## list EXTEND ()

# %%
L= [1,2,3,4,5,6,7,8,9]
print(L)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
## count 
L= [1,2,3,4,5,9,7,8,9,6,7,8,9]
print(L.count(9))
# Out:
# 3

# %%
## index

v= [1,2,3,4,5,6,7,8,9]
print(v.index(6))
# Out:
# 5

# %%
## fromlist()

b= [1,2,3,4,5,6,7,8,9]
print(b)

# %%
## copy()

my=['vishnu',8765468,56949,642486,54165446]

new= my.copy()
print(my)
print(new)
# Out:
# ['vishnu', 8765468, 56949, 642486, 54165446]
# ['vishnu', 8765468, 56949, 642486, 54165446]

# %%
## deepcopy

import copy 
my = copy.deepcopy(new)
print (my)
print (new)
# Out:
# ['vishnu', 8765468, 56949, 642486, 54165446]
# ['vishnu', 8765468, 56949, 642486, 54165446]
