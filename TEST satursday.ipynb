# %%
## task 8

v="Hello "*2
print(v)
# Out:
# Hello Hello

# %%
# Task 9: Predict the output or error:

x = "5" # -----> String
y = 10  #-------> Int
z = 15  #-------> Int
print(x * 3) # string*3  times ## output will be 5 5 5
print(y + z) #two integers addition 10+15=25
print(x + str(y))  ## two string addition perform concatination.
                   ## output: 510 
print(int(x) + y + z)  ## with the help of type casting all
                       ## datatypes converting into one datatype.
                       ## 5+10+15
                       ## output will show : 30
# Out:
# 555
# 25
# 510
# 30

# %%
# Task 10: Using variables and print(), generate:

"""
====================
SHOP RECEIPT
====================
Item : Pen
Quantity : 5
Price     : 10
Total     : 50
====================

"""
print("====================")
print("SHOP RECEIPT")
print("====================")
a="Pen"
b=5
c=10
d=50
print("Item: ",a)
print("Quantity: ",b)
print("Price: ",c)
print("-"*20)
print("Total: ",d)
print("====================")
# Out:
# ...
# SHOP RECEIPT
# ...
# Item:  Pen
# Quantity:  5
# Price:  10
# --------------------
# Total:  50
# ...

# %%
# Task 11: Find the output and Explain sep attribute

# SEP attribute is performing a separations with special character in string

print("A", "B", "C", sep="-")  # A-B-C

print("X", "Y", "Z", sep="***") # X***Y***Z
# Out:
# A-B-C
# X***Y***Z

# %%
# Task 12: Find the output and Explain end attribute



print("Python", end=" ") #end attribute is separating with special
                         ## character, and add a basic functions 
                         ## "print()" in a single line.
print("Programming")

# OUTPUT: Python Programming

# %%
# Task 13: Write a program that displays the following report:

print("-"*20)
print("STUDENT REPORT")
print("-"*20)
a="Alice"
b=21
c=87
print("Name: ",a)
print("Age: ",b)
print("Marks: ",c)

print("-"*20)
# Out:
# --------------------
# STUDENT REPORT
# --------------------
# Name:  Alice
# Age:  21
# Marks:  87
# --------------------

# %%
# Task 14: Predict the output:
a = "10"
b = "20"
c = 30

print(a + b)  ## 1020 because 2 string performs addition while concatination
print(int(a) + int(b)) ## two integer performs the addtion using typecasting 
print(a + str(c)) ## string+string "concatination"
# Out:
# 1020
# 30
# 1030

# %%
# Task 15:  How many spaces appear in each output line?

print("Hello" + " " + "World") #1 space occur 
print("Hello", "World") #v1 space occur
print("Hello" + "World") # 0 space occur
# Out:
# Hello World
# Hello World
# HelloWorld

# %%
# Task 16:  Using print()
# Print the following exactly:

print("Name:"+'"Python"')
print("Course:"+'"Programming"')
# Out:
# Name:"Python"
# Course:"Programming"

# %%
# Task 17: Using only print() statements, display:

print("*")
print("**")
print("***")
print("****")
print("*****")
# Out:
# *
# **
# ***
# ****
# *****

# %%
# Task 18: Fix the code without changing the variable values.

name = "John"
marks = 95
print("Student: ", name)
print("Marks: ", marks)
# Out:
# Student:  John
# Marks:  95

# %%
# Task 19: Find the output.

print("A" + "B", "C" + "D")  ##AB CD
print("A", "B" + "C", "D")   ##A BC D
# Out:
# AB CD
# A BC D

# %%
# Task 20:  Write a single print() statement that displays:

print("Python Java C++")
print("Python","Java","C++")
print(input())
# Out:
# Python Java C++
# Python Java C++
#  Python Java C++
# Python Java C++

# %%
# Task 21: Explain why each line produces a different result.
# Predict the output:

print("10" + "20") ## two string is concat 1020
print(10 + 20) ## two integers perform addition operation
print("10", "20") ## two string separates the ,
# Out:
# 1020
# 30
# 10 20

# %%
# Task 22: Without using commas, produce:
# Welcome to Python Programming
# using only the "+" operator

a="Welcome " 
b="to "
c="Python "
d="Programming"
print(a+b+c+d)
# Out:
# Welcome to Python Programming

# %%
# Task 23: Draw the exact output.
print("A")
print()
print("B")
print()
print()
print("C")
# Out:
# A
#
# B
#
#
# C

# %%
# Task 24:
# NO.
# String + variable not right syntax.
# correct way :string,variable.

age = 20
print("Age is:" ,age)
# Out:
# Age is: 20

# %%
# Task 25: What is the difference between the two outputs?

print("Python" + "3") # two strings are made concatination with addition operator
print("Python","3") # print two strings with separat with  "," ▽ cause of this there is space
# Out:
# Python3
# Python 3

# %%
# Task 26: Write a program using string function with replacement operator {}
##  string operator with replacement {} 

name= 'VISHNU'
address='NANDANVAMN'
salary=66000.00
print("1.Using format")
print("Hello {} your address is {} and your salary {} and we are waiting for our approvel.".format(name,address,salary))
print("2.By indexing")
print("Hello {x} your address is {y} and your salary {z} and we are waiting for our approvel.".format(x=name,y=address,z=salary))
print("3.By variable name")
print(f"Hello {name} your address is {address} and your salary {salary} and we are waiting for our approvel.")
# Out:
# 1.Using format
# Hello VISHNU your address is NANDANVAMN and your salary 66000.0 and we are waiting for our approvel.
# 2.By indexing
# Hello VISHNU your address is NANDANVAMN and your salary 66000.0 and we are waiting for our approvel.
# 3.By variable name
# Hello VISHNU your address is NANDANVAMN and your salary 66000.0 and we are waiting for our approvel.

# %%
# Task 27: Print using \n and \ in string and explain difference between them

print("Hello!\nStudents\nWELCOME TO SOFTRONIX")

print()

print("Hello! " \
      "Students " \
      "WELCOME TO SOFTRONIX")
# Out:
# Hello!
# Students
# WELCOME TO SOFTRONIX
#
# Hello! Students WELCOME TO SOFTRONIX

# %%
# Task 28: Take two variable from user and write a program that accepts:
# •	Name 
# •	Age 
# and displays:
# Name: John
# Age: 20

name=input("Enter Your Name")
age=int(input())

print("Name :",name)
print("Age :",age)
# Out:
# Enter Your Name vishnu
#  20
# Name : vishnu
# Age : 20

# %%
# Task 29: Take two numbers from the user and display their sum.

num1=int(input())
num2=int(input())
print("SUM :",num1+num2)
# Out:
#  2
#  10
# SUM: 12

# %%
# Task 30: Take the input from the user and print:
# Hello, John! Welcome to Python.

userinput=str(input())
print(userinput)
# Out:
#  Hello, John! Welcome to Python.
# Hello, John! Welcome to Python.

# %%
# Task 31: Take the input from the user 
# •	Name 
# •	Roll Number 
# •	Marks 

name=str(input())
roll_no=int(input())
marks=int(input())

print("-"*20)
print("STUDENT REPORT")
print("-"*20)
print("Name :",name)
print("Roll_No :",roll_no)
print("Marks :",marks)
print("-"*20)
# Out:
#  vishnu
#  7410
#  70
# --------------------
# STUDENT REPORT
# --------------------
# Name : vishnu
# Roll_No : 7410
# Marks : 70
# --------------------

# %%
# Task 32: Take the input from the user length and width.
# Display:
# •	Area 
# •	Perimeter

# %%
# Task 33: Take the input from the user and print amount in dollars and convert it to rupees.
# Assume: 1 Dollar = 83 Rupees

# %%
# Task 34: Take the input from the user marks in 5 subjects.

# %%
# Task 35: Simple Interest Calculator
# Take the input from the user 
# •	Principal 
# •	Rate 
# •	Time 
# Calculate:
P=int(input("Principal"))
R=int(input("Rate"))
T=int(input("Time"))

SI = (P * R * T) / 100

print(SI)
# Out:
# Principal 10
# Rate 20
# Time 30
# 60.0

# %%
# Task 36: Take two numbers from the user and display them after swapping.

# %%
# Task 37: Bill Generator
# Take input from user:
# •	Product Name 
# •	Quantity 
# •	Price per Unit 
# Display:

product_name=str(input())
quantity=int(input())
price=int(input())

print("="*20)
print("BILL-RECIPT")
print("="*20)
print("Product  :",product_name)
print("quantity :",quantity)
print("Price    :",price)
print("="*20)
print("Total :",quantity*price)
# Out:
#  pen
#  5
#  10
# ...
# BILL-RECIPT
# ...
# Product  : pen
# quantity : 5
# Price    : 10
# ...
# Total : 50

# %%
# Task 38: User Profile Generator
# Take input from the user:
# •	Name 
# •	Age 
# •	City 
# •	Course 
# Display:

name=str(input())
age=int(input())
city=str(input())
course=str(input())

print("-"*20)
print("USER-PROFILE")
print("-"*20)
print("Name   :",name)
print("Age    :",age)
print("City   :",city)
print("Course :",course)
print("-"*20)
# Out:
#  VISHNU
#  22
#  NGP
#  PYTHON
# --------------------
# USER-PROFILE
# --------------------
# Name   : VISHNU
# Age    : 22
# City   : NGP
# Course : PYTHON
# --------------------

# %%
# Task 39: Temperature Converter
# Take the input from user temperature in Celsius and display Fahrenheit.
# Formula:

c=int(input())
f = int((c * 9/5) + 32)
print(f)
# Out:
#  40
# 104

# %%
# Task 40: College ID Card Generator
# Take input:
# •	Name 
# •	Roll Number 
# •	Branch 
# •	Year 
# Display:

name=str(input("Name"))
roll=int(input("Roll_No"))
branch=str(input("Branch"))
year=int(input("Year"))

print("-"*20)
print("COLLEGE-ID-CARD")
print("-"*20)
print("Name    :",name)
print("Roll_no :",roll)
print("Brance  :",branch)
print("Year    :",year)
print("-"*20)
# Out:
# Name vishnu
# Roll_No 7410
# Branch computer technology
# Year 4
# --------------------
# COLLEGE-ID-CARD
# --------------------
# Name    : vishnu
# Roll_no : 7410
# Brance  : computer technology
# Year    : 4
# --------------------

# %%
# Task 41: Predict the Output

name = input("Enter Name: ")
age = input("Enter Age: ")

print("Name:", name)
print("Age:", age)

# Explain: Why is age treated as a string even if the user enters 20?
# Out:
# Enter Name:  vishnu
# Enter Age:  23
# Name: vishnu
# Age: 23

# %%
# Task 42: Write a program to read 2 numbers from user and print sum

num1=int(input())
num2=int(input())
print("SUM :",num1+num2)
# Out:
#  10
#  20
# SUM : 30

# %%
# Task 43: Write a program to read Employee Data from user and print data

name=str(input("Name"))
age=int(input("Age"))
city=str(input("City"))
department=str(input("Department"))
print()
print("-"*20)
print("EMPLOYEE-DATA")
print("-"*20)
print("Name       :",name)
print("Age        :",age)
print("City       :",city)
print("Department :",department)
print("-"*20)
# Out:
# Name vishnu
# Age 23
# City ngp
# Department ct
# --------------------
# EMPLOYEE-DATA
# --------------------
# Name       : vishnu
# Age        : 23
# City       : ngp
# Department : ct
# --------------------

# %%
# Task 44: How to read multiple values from the keyboard in the single line
print(input().split())
# Out:
#  vishnu ambadi kuhi nagpur
# ['vishnu', 'ambadi', 'kuhi', 'nagpur']

# %%
# Task 45: Write a program to read 3 float numbers from user with (,) comma separator and print their sum

# %%
# Task 46: Explain Eval with example

# %%
# Task 47: Determine the data type of the following variables:
a = 10 # int
b = 10.5 #float 
c = "Hello" #string
d = True # boolean

print(a,b,c,d)

# print(type(a))
# print(type(b))
# print(type(c))
# print(type(d))
# Out:
# 10 10.5 Hello True

# %%
# Task 48: Convert an integer into a float.

v=123
print(float(v))
# Out:
# 123.0

# %%
# Task 49: Convert a float into an integer
v=741.741
print(int(v))
# Out:
# 741

# %%
# Task 50: Convert the following string into an integer and add 10.

v="5"
x=int(v)
c=10
print(x+c)
print(type(x))
# Out:
# 15
# <class 'int'>

# %%
# Task 51: Convert the string into a float

b=("7899654")
print(float(b))
# Out:
# 7899654.0

# %%
# Task 52: Convert an integer into a string and concatenate it with text.

a=415236
b=str(a)
c="text"
print(b+c)
print(type(b))
# Out:
# 415236text
# <class 'str'>

# %%
# Task 53: Take user input for age and convert it into an integer.

age=input()
a=int(age)
print(type(a))
# Out:
#  20
# <class 'int'>

# %%
# Task 54: Take two numbers as input from the user and display their sum.

inp1=int(input("Num1"))
inp2=int(input("Num2"))
summ=(inp1+inp2)
print(summ)
# Out:
# Num1 20
# Num2 30
# 50

# %%
# Task 55: Convert the following values into Boolean: 0, 1,””,” Python”

a= 0
b=1
c=""
d="Python"
e=bool(a)
f=bool(b)
g=bool(c)
h=bool(d)

print(e)
print(f)
print(g)
print(h)
# Out:
# False
# True
# False
# True

# %%
# Task 56: Create a simple calculator that takes
#two numbers from the user and performs:
# •	Addition 
# •	Subtraction 
# •	Multiplication 
# •	Division 


num1=float(input("Enter first number :"))
num2=float(input("Enter second number :"))

print("ADDITION :", num1+num2)
print("SUBTRACTION :", num1-num2)
print("MULTIPLICATION :", num1*num2)
print("DIVISION :", num1/num2)
# Out:
# Enter first number : 6
# Enter second number : 12
# ADDITION : 18.0
# SUBTRACTION : -6.0
# MULTIPLICATION : 72.0
# DIVISION : 0.5

# %%
# Task 57: What is Type Casting in Python? 

# typecasting is in python, converting a one datatype is into another datatype calling as typecasting

# %%
# Task 58: Convert int, str, bool, complex into float

v=int(input("enter int :"))
b=float(v)
print(b)
print(type(b))

a=str(input("enter str :"))
s=float(a)
print(s)
print(type(s))

v=bool(input("enter bool :"))
b=float(v)
print(b)
print(type(b))

x=int(input("enter complex :"))
y=float(x)
print(y)
print(type(y))
# Out:
# enter int : 45
# 45.0
# <class 'float'>
# enter str : v
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 9
#       5 print(b)
#       6 print(type(b))
#       7
#       8 a=str(input("enter str :"))
# ----> 9 s=float(a)
#      10 print(s)
#      11 print(type(s))
#      12
#
# ValueError: could not convert string to float: 'v'

# %%
# Task 59: Convert int, float, bool, complex into str

v=int(input("enter input :"))
b=str(v)
print(b)
print(type(b))

v=float(input("enter input :"))
b=str(v)
print(b)
print(type(b))

v=bool(input("enter input :"))
b=str(v)
print(b)
print(type(b))

v=complex(input("enter input :"))
b=str(v)
print(b)
print(type(b))
# Out:
# enter input : 4
# 4
# <class 'str'>
# enter input : 12.0
# 12.0
# <class 'str'>
# enter input : 45
# True
# <class 'str'>
# enter input : 4
# (4+0j)
# <class 'str'>

# %%
# Task 60: Convert int, str, bool, float into complex

# %%
# Task 61: Convert int, str, float, complex into bool

# %%
# Task 62: Write a program to add two numbers.

# %%
# Task 63: Find the difference between two numbers.

# %%
# Task 64: Multiply two numbers.

# %%
# Task 65: Divide one number by another.

# %%
# Task 66: Find Remainder Use the modulus operator %.

# %%
# Task 70: Area of Rectangle Take length and breadth from the user and calculate area.
# Formula: Area = Length × Breadth

length=float(input("length"))
breadth=float(input("breasth"))
area = length*breadth

print(area)
# Out:
# length 41
# breasth 65
# 2665.0

# %%
# Task 71: Take three numbers and calculate their average.

# %%
# Task 72: Area of Circle Take radius as input and calculate area.Formula: Area = 3.14 × r × r

r=float(input("radius"))
area = 3.14 * r* r
print(area)
# Out:
# radius 14.2
# 633.1496

# %%
# Task 73: Calculate Simple Interest. Formula: SI = (P × R × T) / 100
P=float(input("P"))
R=float(input("R"))
T=float(input("T"))
SI = P * R * T/ 100
print()
print(SI)
# Out:
# P 41
# R 5
# T 5
# 10.25

# %%
# Task 74: Take marks of 5 subjects and calculate:
# •	Total Marks 
# •	Percentage
