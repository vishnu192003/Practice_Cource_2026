# %% [markdown]
# ## practice of my python session

# %%
# Quick creation of an array of squares

squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
import math
result = math.gcd(24, 60) # Returns 12
print(result)
# Out:
# 12

# %%
arr = [1, 34, 3, 98, 9, 76, 45, 4]

arr.sort(reverse=True)

result = "".join(map(str, arr))

print(result)
# Out:
# 987645349431

# %%
arr = [3,7,2,9,5,20]
largest = arr[0]
for num in arr:
    if num > largest:
        largest = num

print(largest)
# Out:
# 20
